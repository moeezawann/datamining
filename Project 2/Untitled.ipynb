# %% [markdown]
# # Project 2

# %%
# %pip install requests bs4 tqdm
from bs4 import BeautifulSoup
import requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://www.basketball-reference.com/contracts/players.html'

page = requests.get(url)
page.encoding = 'utf-8'  # Explicitly setting encoding rule because names like "Nikola Jokić" were printing out like "Nikola JokiÄ" 


soup = BeautifulSoup(page.text, 'html')

# %%
#print(soup)

# %%
soup.find('table', class_ = 'sortable stats_table' )
# Out:
# <table class="sortable stats_table" data-cols-to-freeze=",2" id="player-contracts">
# <caption>427 Contracts Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr class="over_header">
# <th aria-label="" class="over_header center" colspan="3" data-stat=""></th>
# <th aria-label="" class="over_header center" colspan="6" data-stat="header_salary">Salary</th><th></th>
# </tr>
# <tr>
# <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting right" data-stat="ranker" data-tip="Rank" scope="col">Rk</th>
# <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th>
# <th aria-label="Tm" class="poptip sort_default_asc left" data-stat="team_id" data-tip="Team" scope="col">Tm</th>
# <th aria-label="2024-25" class="poptip center" data-over-header="Salary" data-stat="y1" scope="col">2024-25</th>
# ...

# %% [raw]
# using table to find the table since there is only one this is not an issue but if we had mutiple using the class name can help hone down on which one we are exactly looking for

# %%
rows = soup.find_all('tr')
players_name = []
# Loop through each row and find the player name
for row in rows:
    player_cell = row.find('td', {'data-stat': 'player'}) 
    if player_cell:
        players_name = player_cell.get_text()
        
name = "Tyrese Maxey"
if name in players_name:
    print("yes")

# %% [raw]
# I am doing this because I will be training the data set on two previous years. However I only want it to predict for players that will be playing this season. Hence why I scraped this website "https://www.basketball-reference.com/contracts/players.html" to get all the players who still have contracts for this season. Some of these players may not have even played the last 2 years so if they do not appear in the previous 2 years worth of data I will drop them from model. Or if they are rookies I will be dropping them fro, the model since there isn't much data asides from college which I am not using.

# %% [markdown]
# ## Now we can import our data sets and data frames
